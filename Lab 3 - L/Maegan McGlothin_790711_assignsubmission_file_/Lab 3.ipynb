# %% [markdown]
# # Lab 3
#
# By: Maegan McGlothin and Andrew White

# %%
x1 = 0
x2 = 2

def f(x):
    return (x^3)/2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return (x^3)/2

var('x, h')
(f(x + h) - f(x))/h
# Out:
# 1/2*((h + x)^3 - x^3)/h

# %%
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# 1/2*h^2 + 3/2*h*x + 3/2*x^2

# %%
(plot(x^3/2, x, 0, 2)+plot(3*x/2-1, 0, 2, rgbcolor='red')+point((1, 1/2), \
    rgbcolor='black', pointsize=30)).show(xmin=0, xmax=2, ymin=-1, ymax=4)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
(plot(3/x, x, -3, 0)+plot(-3*x/4-3, -3, 0, rgbcolor='red')+point((-2, -3/2), \
    rgbcolor='black', pointsize=30)).show(xmin=-3, xmax=0, ymin=-10, ymax=0)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
x1 = 2
x2 = 3

def f(x):
    return (4*x)

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 5)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=5, ymin=0, ymax=12)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return 4*x

var('x, h')
(f(x + h) - f(x))/h
# Out:
# 4

# %%
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# 4

# %%
(plot(4*x, x, 1, 3)+plot(4*x, 1, 3, rgbcolor='red')+point((2, 8), \
    rgbcolor='black', pointsize=30)).show(xmin=0, xmax=5, ymin=0, ymax=12)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
x1 = 1
x2 = 2

def f(x):
    return (-3*x^2)+2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 1, 2)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=5, ymin=-10, ymax=1)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return (-3*x^2)+2

var('x, h')
(f(x + h) - f(x))/h
# Out:
# -3*((h + x)^2 - x^2)/h

# %%
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# -5/(h*x + x^2)

# %%
(plot(-3*x^2+2, x, 0, 2)+plot(-6*x+5, 0, 2, rgbcolor='red')+point((1, 1/2), \
    rgbcolor='black', pointsize=30)).show(xmin=0, xmax=5, ymin=-10, ymax=1)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
x1 = 4
x2 = 6

def f(x):
    return (5/x)+3

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 8)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=10, ymin=0, ymax=5)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return (5/x)+3

var('x, h')
(f(x + h) - f(x))/h
# Out:
# 5*(1/(h + x) - 1/x)/h

# %%
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# -5/(h*x + x^2)

# %%
(plot((5/x)+3, x, 0, 8)+plot(-1/5*(x-5)+4, 2, 6, rgbcolor='red')+point((5, 4), \
    rgbcolor='black', pointsize=30)).show(xmin=0, xmax=10, ymin=-1, ymax=8)
# Out:
# Graphics object consisting of 3 graphics primitives
