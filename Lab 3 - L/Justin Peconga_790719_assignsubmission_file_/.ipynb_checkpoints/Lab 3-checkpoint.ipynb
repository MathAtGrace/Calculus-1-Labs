# %% [markdown]
# # Lab 3
#
# Justin Peconga, Isaac Hertzler

# %%
x1 = 0
x2 = 2

def f(x):
    return (x^3)/2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
x1 = 0.5
x2 = 1.5

def f(x):
    return (x^3)/2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
x1 = 0.999
x2 = 1.001

def f(x):
    return (x^3)/2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return (x^3)/2

var('x, h')
(f(x + h) - f(x))/h
# Out:
# 1/2*((h + x)^3 - x^3)/h

# %%
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# 1/2*h^2 + 3/2*h*x + 3/2*x^2

# %%
((f(x + h) - f(x))/h).rational_simplify().subs(h=0)
# Out:
# 3/2*x^2

# %%
(plot(x^3/2, x, 0, 2)+plot(3*x/2-1, 0, 2, rgbcolor='red')+point((1, 1/2), \
    rgbcolor='black', pointsize=30)).show(xmin=0, xmax=2, ymin=-1, ymax=4)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
(plot(3/x, x, -3, 0)+plot(-3*x/4-3, -3, 0, rgbcolor='red')+point((-2, -3/2), \
    rgbcolor='black', pointsize=30)).show(xmin=-3, xmax=0, ymin=-10, ymax=0)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# # Pactice Problems
#
# 1.

# %%
def f(x):
    return (4*x)

var('x, h')
(f(x + h) - f(x))/h
# Out:
# 4

# %% [markdown]
# 2.

# %%
def f(x):
    return (-3*x^2)+2

var('x, h')
(f(x + h) - f(x))/h
# Out:
# -3*((h + x)^2 - x^2)/h

# %%
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# -3*h - 6*x

# %%
((f(x + h) - f(x))/h).rational_simplify().subs(h=0)
# Out:
# -6*x

# %%
(-6*x).rational_simplify().subs(x=1)
# Out:
# -6

# %% [markdown]
# 3.

# %%
def f(x):
    return (5/x)+3

var('x, h')
(f(x + h) - f(x))/h
# Out:
# 5*(1/(h + x) - 1/x)/h

# %%
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# -5/(h*x + x^2)

# %%
((f(x + h) - f(x))/h).rational_simplify().subs(h=0)
# Out:
# -5/x^2

# %%
(-5/x^2).rational_simplify().subs(x=5)
# Out:
# -1/5

# %% [markdown]
# # Practice Questions
#
# 1. 4
# 2. -6x or -6
# 3. -5/x^2 or -1/5

# %% [markdown]
# # Graphs
#
# 1.

# %%
x1 = 0
x2 = 2

def f(x):
    return 4*x

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %% [markdown]
# 2.

# %%
x1 = 0
x2 = 2

def f(x):
    return (-3*x^2)+2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=-3, xmax=3, ymin=-9, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
x1 = 1
x2 = 2

def f(x):
    return (5/x)+3

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=5, ymin=-1, ymax=15)
# Out:
# Graphics object consisting of 7 graphics primitives
