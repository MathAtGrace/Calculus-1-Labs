# %% [markdown]
# <center>
# Lab 3
#     <center>
# <center>
# By Josiah Thompson, Tye Wade, & Elijah Patterson
#     <center>

# %% [markdown]
# Example Problem #1

# %%
x1 = .5
x2 = 1.5

def f(x):
    return (x^3)/2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
x1 = .999
x2 = 1.001

def f(x):
    return (x^3)/2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return (x^3)/2

var('x, h')
(f(x + h) - f(x))/h
# Out:
# 1/2*((h + x)^3 - x^3)/h

# %%
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# 1/2*h^2 + 3/2*h*x + 3/2*x^2

# %%
((f(x + h) - f(x))/h).rational_simplify().subs(h=0)
# Out:
# 3/2*x^2

# %%
3/2*1^2
# Out:
# 3/2

# %%
(plot(x^3/2, x, 0, 2)+plot(3*x/2-1, 0, 2, rgbcolor='red')+point((1, 1/2), \
    rgbcolor='black', pointsize=30)).show(xmin=0, xmax=2, ymin=-1, ymax=4)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# Practice Problem #1

# %%
x1 = 1.5
x2 = 2.5

def f(x):
    return 4*x

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
x1 = 1.999
x2 = 2.001

def f(x):
    return 4*x

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return 4*x

var('x, h')
(f(x + h) - f(x))/h
# Out:
# 4

# %%
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# 4

# %%
((f(x + h) - f(x))/h).rational_simplify().subs(h=0)
# Out:
# 4

# %%
(plot(4*x, x, 0, 2)+plot(4*x, 0, 2, rgbcolor='red')+point((2, 1/2), \
    rgbcolor='black', pointsize=30)).show(xmin=0, xmax=2, ymin=-1, ymax=4)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# Practice Problem #2

# %%
x1 = .5
x2 = 1.5

def f(x):
    return (-3*x^2)+2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, -4, 4)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=-4, xmax=4, ymin=-7, ymax=4)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
x1 = .999
x2 = 1.001

def f(x):
    return (-3*x^2)+2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, -4, 4)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=-4, xmax=4, ymin=-7, ymax=4)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return (-3*x^2)+2

var('x, h')
(f(x + h) - f(x))/h
# Out:
# -3*((h + x)^2 - x^2)/h

# %%
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# -3*h - 6*x

# %%
((f(x + h) - f(x))/h).rational_simplify().subs(h=0)
# Out:
# -6*x

# %%
(plot(-6*x+5, x, -4, 4)+plot((-3*x^2)+2, -3, 3, rgbcolor='red')+point((1, -1), \
    rgbcolor='black', pointsize=30)).show(xmin=-4, xmax=4, ymin=-10, ymax=4)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# Practice Problem #3

# %%
x1 = 4.5
x2 = 5.5

def f(x):
    return 5/x+3

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, -1, 9)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=-1, xmax=10, ymin=-5, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
x1 = 4.999
x2 = 5.001

def f(x):
    return 5/x+3

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, -1, 9)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=-1, xmax=10, ymin=-5, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return (5/x)+3

var('x, h')
(f(x + h) - f(x))/h
# Out:
# 5*(1/(h + x) - 1/x)/h

# %%
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# -5/(h*x + x^2)

# %%
((f(x + h) - f(x))/h).rational_simplify().subs(h=0)
# Out:
# -5/x^2

# %%
(plot((5/x)+3, x, -10, 10)+plot((-5/5^2)*(x-5)+4, -10, 10, rgbcolor='red')+point((5, 4), \
    rgbcolor='black', pointsize=30)).show(xmin=-10, xmax=10, ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 3 graphics primitives
