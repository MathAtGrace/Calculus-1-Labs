# %% [markdown]
# # Lab 3
#
# Tye Wade, Elijah Patterson, Josiah Thompson

# %%
x1 = 0
x2 = 2

def f(x):
    return (x^3)/2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
x1 = 0.5
x2 = 1.5

def f(x):
    return (x^3)/2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
x1 = .999
x2 = 1.001

def f(x):
    return (x^3)/2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return (x^3)/2

var('x, h')
(f(x + h) - f(x))/h
# Out:
# 1/2*((h + x)^3 - x^3)/h

# %%
def f(x):
    return (x^3)/2

var('x, h')
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# 1/2*h^2 + 3/2*h*x + 3/2*x^2

# %%
def f(x):
    return (x^3)/2

var('x, h')
((f(x + h) - f(x))/h).rational_simplify().subs(h=0)
# Out:
# 3/2*x^2

# %%
3/2*1^2
# Out:
# 3/2

# %%
(plot(x^3/2, x, 0, 2)+plot(3*x/2-1, 0, 2, rgbcolor='red')+point((1, 1/2), \
    rgbcolor='black', pointsize=30)).show(xmin=0, xmax=2, ymin=-1, ymax=4)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# <underline>Practice Problem 1
# </underline>

# %%
x1 = 1.5
x2 = 2.5

def f(x):
    return 4*x

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, 0, 3)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=0, xmax=3, ymin=-1, ymax=9)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return 4*x

var('x, h')
(f(x + h) - f(x))/h
# Out:
# 4

# %%
def f(x):
    return 4*x

var('x, h')
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# 4

# %%
def f(x):
    return 4*x

var('x, h')
((f(x + h) - f(x))/h).rational_simplify().subs(h=0)
# Out:
# 4

# %%
(plot(4*x, x, 0, 2)+plot(4*x, 0, 2, rgbcolor='red')+point((2, 8), \
    rgbcolor='black', pointsize=30)).show(xmin=0, xmax=2, ymin=-1, ymax=4)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [raw]
# Practice Problem 2

# %%
x1 = .5
x2 = 1.5

def f(x):
    return -3*(x^2)+2

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, -4, 4)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=-4, xmax=4, ymin=-6, ymax=6)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return -3*(x^2)+2

var('x, h')
(f(x + h) - f(x))/h
# Out:
# -3*((h + x)^2 - x^2)/h

# %%
def f(x):
    return -3*(x^2)+2

var('x, h')
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# -3*h - 6*x

# %%
def f(x):
    return -3*(x^2)+2

var('x, h')
((f(x + h) - f(x))/h).rational_simplify().subs(h=0)
# Out:
# -6*x

# %%
(plot(-3*(x^2)+2, x, -2, 2)+plot(-6*(x-1)-1, -2, 2, rgbcolor='red')+point((1, -1), \
    rgbcolor='black', pointsize=30)).show(xmin=-2, xmax=2, ymin=-4, ymax=3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# Practice Problem 3

# %% [markdown]
# We changed the varible from t to x to statisfy the code.

# %%
x1 = 4.5
x2 = 5.5

def f(x):
    return (5/x)+3

y1 = f(x1)
y2 = f(x2)

slope = (y2-y1)/(x2-x1)

p = plot(f(x), x, -6, 6)
pt1 = point((x1, y1), rgbcolor=(1,0,0), pointsize=30)
pt2 = point((x2, y2), rgbcolor=(1,0,0), pointsize=30)

d = 3
l = line([(x1-d, y1-d*slope), (x2+d, y2+d*slope)], rgbcolor=(1,0,0))

t1 = text("(%s, %s)" % (float(x1), float(y1)), (x1+0.5, y1-0.8), rgbcolor=(1,0,0))
t2 = text("(%s, %s)" % (float(x2), float(y2)), (x2+0.5, y2-0.8), rgbcolor=(1,0,0))
t3 = text("slope: %s" % float(slope), ((x1+x2)/2-0.5, (y1+y2)/2), rgbcolor=(1,0,0))

g = p+pt1+pt2+l+t1+t2+t3
g.show(xmin=3.5, xmax=6, ymin=3.5, ymax=6)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def f(x):
    return (5/x)+3

var('x, h')
(f(x + h) - f(x))/h
# Out:
# 5*(1/(h + x) - 1/x)/h

# %%
def f(x):
    return (5/x)+3

var('x, h')
((f(x + h) - f(x))/h).rational_simplify()
# Out:
# -5/(h*x + x^2)

# %%
def f(x):
    return (5/x)+3

var('x, h')
((f(x + h) - f(x))/h).rational_simplify().subs(h=0)
# Out:
# -5/x^2

# %%
(plot((5/x)+3, x, -6, 8)+plot((-5/5^2)*(x-5)+4, -6, 8, rgbcolor='red')+point((5, 4), \
    rgbcolor='black', pointsize=30)).show(xmin=1, xmax=8, ymin=3, ymax=6)
# Out:
# Graphics object consisting of 3 graphics primitives
